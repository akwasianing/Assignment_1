# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load cleaned_frailty_data
df = pd.read_csv('https://raw.githubusercontent.com/akwasianing/Assignment_1/refs/heads/main/frailty_project/data_clean/cleaned_frailty_data.csv')
df
# Out:
#    Height  Weight  Age  Grip strength Frailty
# 0    65.8     112   30             30       N
# 1    71.5     136   19             31       N
# 2    69.4     153   45             29       N
# 3    68.2     142   22             28       Y
# 4    67.8     144   29             24       Y
# 5    68.7     123   50             26       N
# 6    69.8     141   51             22       Y
# 7    70.1     136   23             20       Y
# 8    67.9     112   17             19       N
# 9    66.8     120   39             31       N

# %%
# Display Basic Statistics
summary = df.describe()
print(summary)

# Save summary statistics
summary.to_csv("result.txt")
# Out:
#           Height      Weight        Age  Grip strength
# count  10.000000   10.000000  10.000000      10.000000
# mean   68.600000  131.900000  32.500000      26.000000
# std     1.670662   14.231811  12.860361       4.521553
# min    65.800000  112.000000  17.000000      19.000000
# 25%    67.825000  120.750000  22.250000      22.500000
# 50%    68.450000  136.000000  29.500000      27.000000
# 75%    69.700000  141.750000  43.500000      29.750000
# max    71.500000  153.000000  51.000000      31.000000

# %%
sns.histplot(x='Grip strength', data=df, stat='density', kde=True)
# Out:
# <Axes: xlabel='Grip strength', ylabel='Density'>

# %%
# Plotting a scatter plot to visualize the relationship between 'Height' and 'Grip strength' columns
sns.scatterplot(x='Height', y='Grip strength', data=df)
# Out:
# <Axes: xlabel='Height', ylabel='Grip strength'>
